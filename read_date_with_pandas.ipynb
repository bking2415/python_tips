# %%
import pandas as pd

# %%
# Read CSV file to DataFrame (table)
df = pd.read_csv('data/MonthlySales.csv')

# %%
# Print DataFrame
df.head()
# Out:
#         month     sales
# 0  2013-01-01  14236.90
# 1  2013-02-01   4519.89
# 2  2013-03-01  55691.01
# 3  2013-04-01  28295.35
# 4  2013-05-01  23648.29

# %%
import json
from pandas.io.json import json_normalize

with open('data/monthlySalesbyCategoryMultiple.json') as json_data:
    d = json.load(json_data)

# %%
# Normalize data into a table
df = json_normalize(d['contents'], 'monthlySales', ['category', 'region'])
# Out:
# /var/folders/r7/mrbyjvpj18dctpwycrd_v8l40000gn/T/ipykernel_2065/1565843720.py:2: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   df = json_normalize(d['contents'], 'monthlySales', ['category', 'region'])

# %%
# Print JSON File
df
# Out:
#        month  sales    category region
# 0   20130101     38   Furniture   West
# 1   20130201     35   Furniture   West
# 2   20130301     41   Furniture   West
# 3   20130401     55   Furniture   West
# 4   20130501     58   Furniture   West
# 5   20130601     66   Furniture   West
# 6   20130701     74   Furniture   West
# 7   20130801     78   Furniture   West
# 8   20130901     38   Furniture   West
# 9   20131001     30   Furniture   West
# 10  20131101     26   Furniture   West
# 11  20131201     29   Furniture   West
# 12  20130101     54  Technology   West
# 13  20130201     66  Technology   West
# 14  20130301     77  Technology   West
# 15  20130401     70  Technology   West
# 16  20130501     60  Technology   West
# 17  20130601     63  Technology   West
# 18  20130701     55  Technology   West
# 19  20130801     47  Technology   West
# 20  20130901     55  Technology   West
# 21  20131001     30  Technology   West
# 22  20131101     22  Technology   West
# 23  20131201     77  Technology   West

# %%
#reading parquet into panda dataframe
import pyarrow.parquet as pq

# %%
table = pq.read_table('data/MonthlyProductSales.parquet')

# %%
# Convert to table
table.to_pandas()
# Out:
#      Month of Order Date                                       Product Name  \
# 0          b'2017-01-13'                                      b'Xerox 1972'
# 1          b'2017-01-13'                                      b'Xerox 1923'
# 2          b'2017-01-13'                                       b'Xerox 225'
# 3          b'2017-01-13'                                       b'Xerox 195'
# 4          b'2017-01-13'  b'Wireless Extenders zBoost YX545 SOHO Signal ...
# ...                  ...                                                ...
# 9247       b'2017-12-16'    b'14-7/8 x 11 Blue Bar Computer Printout Paper'
# 9248       b'2017-12-16'                    b'6" Cubicle Wall Clock, Black'
# 9249       b'2017-12-16'                b'3M Hangers With Command Adhesive'
# 9250       b'2017-12-16'  b'3.6 Cubic Foot Counter Height Office Refrige...
# 9251       b'2017-12-16'                              b'3-ring staple pack'
#
#       Sales
# 0        11
# 1        37
# 2        19
# 3        40
# 4       756
# ...     ...
# 9247     96
# 9248     10
# 9249     10
# 9250    295
# 9251      9
#
# [9252 rows x 3 columns]

# %%
import html5lib
import lxml
# you need to install html5lib
# pip install html5lib
# reading data from a html site
df = pd.read_html('https://en.wikipedia.org/wiki/List_of_U.S._state_abbreviations')

# %%
# get part that has the states and abbreviations
df_usa = df[0]
df_usa.info()
df_usa.head(12)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 88 entries, 0 to 87
# Data columns (total 10 columns):
#  #   Column                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            Non-Null Count  Dtype
# ---  ------                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            --------------  -----
#  0   Codes:  ISO ISO 3166 codes (2-letter, 3-letter, and 3-digit codes from ISO 3166-1; 2+2-letter codes from ISO 3166-2)  ANSI 2-letter and 2-digit codes from the ANSI standard INCITS 38:2009 (supersedes FIPS 5-2)  USPS 2-letter codes used by the United States Postal Service  USCG 2-letter codes used by the United States Coast Guard (bold red text shows differences between ANSI and USCG) Abbreviations:  GPO Older variable-length official US Government Printing Office abbreviations  AP Abbreviations from the AP Stylebook (bold red text shows differences between GPO and AP)    87 non-null     object
#  1   Codes:  ISO ISO 3166 codes (2-letter, 3-letter, and 3-digit codes from ISO 3166-1; 2+2-letter codes from ISO 3166-2)  ANSI 2-letter and 2-digit codes from the ANSI standard INCITS 38:2009 (supersedes FIPS 5-2)  USPS 2-letter codes used by the United States Postal Service  USCG 2-letter codes used by the United States Coast Guard (bold red text shows differences between ANSI and USCG) Abbreviations:  GPO Older variable-length official US Government Printing Office abbreviations  AP Abbreviations from the AP Stylebook (bold red text shows differences between GPO and AP).1  87 non-null     object
#  2   Codes:  ISO ISO 3166 codes (2-letter, 3-letter, and 3-digit codes from ISO 3166-1; 2+2-letter codes from ISO 3166-2)  ANSI 2-letter and 2-digit codes from the ANSI standard INCITS 38:2009 (supersedes FIPS 5-2)  USPS 2-letter codes used by the United States Postal Service  USCG 2-letter codes used by the United States Coast Guard (bold red text shows differences between ANSI and USCG) Abbreviations:  GPO Older variable-length official US Government Printing Office abbreviations  AP Abbreviations from the AP Stylebook (bold red text shows differences between GPO and AP).2  75 non-null     object
#  3   Codes:  ISO ISO 3166 codes (2-letter, 3-letter, and 3-digit codes from ISO 3166-1; 2+2-letter codes from ISO 3166-2)  ANSI 2-letter and 2-digit codes from the ANSI standard INCITS 38:2009 (supersedes FIPS 5-2)  USPS 2-letter codes used by the United States Postal Service  USCG 2-letter codes used by the United States Coast Guard (bold red text shows differences between ANSI and USCG) Abbreviations:  GPO Older variable-length official US Government Printing Office abbreviations  AP Abbreviations from the AP Stylebook (bold red text shows differences between GPO and AP).3  62 non-null     object
#  4   Codes:  ISO ISO 3166 codes (2-letter, 3-letter, and 3-digit codes from ISO 3166-1; 2+2-letter codes from ISO 3166-2)  ANSI 2-letter and 2-digit codes from the ANSI standard INCITS 38:2009 (supersedes FIPS 5-2)  USPS 2-letter codes used by the United States Postal Service  USCG 2-letter codes used by the United States Coast Guard (bold red text shows differences between ANSI and USCG) Abbreviations:  GPO Older variable-length official US Government Printing Office abbreviations  AP Abbreviations from the AP Stylebook (bold red text shows differences between GPO and AP).4  71 non-null     object
#  5   Codes:  ISO ISO 3166 codes (2-letter, 3-letter, and 3-digit codes from ISO 3166-1; 2+2-letter codes from ISO 3166-2)  ANSI 2-letter and 2-digit codes from the ANSI standard INCITS 38:2009 (supersedes FIPS 5-2)  USPS 2-letter codes used by the United States Postal Service  USCG 2-letter codes used by the United States Coast Guard (bold red text shows differences between ANSI and USCG) Abbreviations:  GPO Older variable-length official US Government Printing Office abbreviations  AP Abbreviations from the AP Stylebook (bold red text shows differences between GPO and AP).5  68 non-null     object
#  6   Codes:  ISO ISO 3166 codes (2-letter, 3-letter, and 3-digit codes from ISO 3166-1; 2+2-letter codes from ISO 3166-2)  ANSI 2-letter and 2-digit codes from the ANSI standard INCITS 38:2009 (supersedes FIPS 5-2)  USPS 2-letter codes used by the United States Postal Service  USCG 2-letter codes used by the United States Coast Guard (bold red text shows differences between ANSI and USCG) Abbreviations:  GPO Older variable-length official US Government Printing Office abbreviations  AP Abbreviations from the AP Stylebook (bold red text shows differences between GPO and AP).6  57 non-null     object
#  7   Codes:  ISO ISO 3166 codes (2-letter, 3-letter, and 3-digit codes from ISO 3166-1; 2+2-letter codes from ISO 3166-2)  ANSI 2-letter and 2-digit codes from the ANSI standard INCITS 38:2009 (supersedes FIPS 5-2)  USPS 2-letter codes used by the United States Postal Service  USCG 2-letter codes used by the United States Coast Guard (bold red text shows differences between ANSI and USCG) Abbreviations:  GPO Older variable-length official US Government Printing Office abbreviations  AP Abbreviations from the AP Stylebook (bold red text shows differences between GPO and AP).7  59 non-null     object
#  8   Codes:  ISO ISO 3166 codes (2-letter, 3-letter, and 3-digit codes from ISO 3166-1; 2+2-letter codes from ISO 3166-2)  ANSI 2-letter and 2-digit codes from the ANSI standard INCITS 38:2009 (supersedes FIPS 5-2)  USPS 2-letter codes used by the United States Postal Service  USCG 2-letter codes used by the United States Coast Guard (bold red text shows differences between ANSI and USCG) Abbreviations:  GPO Older variable-length official US Government Printing Office abbreviations  AP Abbreviations from the AP Stylebook (bold red text shows differences between GPO and AP).8  54 non-null     object
#  9   Codes:  ISO ISO 3166 codes (2-letter, 3-letter, and 3-digit codes from ISO 3166-1; 2+2-letter codes from ISO 3166-2)  ANSI 2-letter and 2-digit codes from the ANSI standard INCITS 38:2009 (supersedes FIPS 5-2)  USPS 2-letter codes used by the United States Postal Service  USCG 2-letter codes used by the United States Coast Guard (bold red text shows differences between ANSI and USCG) Abbreviations:  GPO Older variable-length official US Government Printing Office abbreviations  AP Abbreviations from the AP Stylebook (bold red text shows differences between GPO and AP).9  39 non-null     object
# dtypes: object(10)
# memory usage: 7.0+ KB
#    Codes:  ISO ISO 3166 codes (2-letter, 3-letter, and 3-digit codes from ISO 3166-1; 2+2-letter codes from ISO 3166-2)  ANSI 2-letter and 2-digit codes from the ANSI standard INCITS 38:2009 (supersedes FIPS 5-2)  USPS 2-letter codes used by the United States Postal Service  USCG 2-letter codes used by the United States Coast Guard (bold red text shows differences between ANSI and USCG) Abbreviations:  GPO Older variable-length official US Government Printing Office abbreviations  AP Abbreviations from the AP Stylebook (bold red text shows differences between GPO and AP)  \
# 0                                              Codes:
# 1                                                 ISO
# 2                                                ANSI
# 3                                                USPS
# 4                                                USCG
# 5                                      Abbreviations:
# 6                                                 GPO
# 7                                                  AP
# 8                           Name and status of region
# 9                                                 NaN
# 10                           United States of America
# 11                                            Alabama
#
#    Codes:  ISO ISO 3166 codes (2-letter, 3-letter, and 3-digit codes from ISO 3166-1; 2+2-letter codes from ISO 3166-2)  ANSI 2-letter and 2-digit codes from the ANSI standard INCITS 38:2009 (supersedes FIPS 5-2)  USPS 2-letter codes used by the United States Postal Service  USCG 2-letter codes used by the United States Coast Guard (bold red text shows differences between ANSI and USCG) Abbreviations:  GPO Older variable-length official US Government Printing Office abbreviations  AP Abbreviations from the AP Stylebook (bold red text shows differences between GPO and AP).1  \
# 0                                              Codes:
# 1   ISO 3166 codes (2-letter, 3-letter, and 3-digi...
# 2   2-letter and 2-digit codes from the ANSI stand...
# 3   2-letter codes used by the United States Posta...
# 4   2-letter codes used by the United States Coast...
# 5                                      Abbreviations:
# 6   Older variable-length official US Government P...
# 7   Abbreviations from the AP Stylebook (bold red ...
# 8                           Name and status of region
# 9                                                 NaN
# 10                                      Federal state
# 11                                              State
#
#    Codes:  ISO ISO 3166 codes (2-letter, 3-letter, and 3-digit codes from ISO 3166-1; 2+2-letter codes from ISO 3166-2)  ANSI 2-letter and 2-digit codes from the ANSI standard INCITS 38:2009 (supersedes FIPS 5-2)  USPS 2-letter codes used by the United States Postal Service  USCG 2-letter codes used by the United States Coast Guard (bold red text shows differences between ANSI and USCG) Abbreviations:  GPO Older variable-length official US Government Printing Office abbreviations  AP Abbreviations from the AP Stylebook (bold red text shows differences between GPO and AP).2  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7   Abbreviations from the AP Stylebook (bold red ...
# 8                                                 ISO
# 9                                                 NaN
# 10  .mw-parser-output .monospaced{font-family:mono...
# 11                                              US-AL
#
#    Codes:  ISO ISO 3166 codes (2-letter, 3-letter, and 3-digit codes from ISO 3166-1; 2+2-letter codes from ISO 3166-2)  ANSI 2-letter and 2-digit codes from the ANSI standard INCITS 38:2009 (supersedes FIPS 5-2)  USPS 2-letter codes used by the United States Postal Service  USCG 2-letter codes used by the United States Coast Guard (bold red text shows differences between ANSI and USCG) Abbreviations:  GPO Older variable-length official US Government Printing Office abbreviations  AP Abbreviations from the AP Stylebook (bold red text shows differences between GPO and AP).3  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                ANSI
# 9                                                 NaN
# 10                                                 US
# 11                                                 AL
#
#    Codes:  ISO ISO 3166 codes (2-letter, 3-letter, and 3-digit codes from ISO 3166-1; 2+2-letter codes from ISO 3166-2)  ANSI 2-letter and 2-digit codes from the ANSI standard INCITS 38:2009 (supersedes FIPS 5-2)  USPS 2-letter codes used by the United States Postal Service  USCG 2-letter codes used by the United States Coast Guard (bold red text shows differences between ANSI and USCG) Abbreviations:  GPO Older variable-length official US Government Printing Office abbreviations  AP Abbreviations from the AP Stylebook (bold red text shows differences between GPO and AP).4  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                ANSI
# 9                                                 NaN
# 10                                                 00
# 11                                                 01
#
#    Codes:  ISO ISO 3166 codes (2-letter, 3-letter, and 3-digit codes from ISO 3166-1; 2+2-letter codes from ISO 3166-2)  ANSI 2-letter and 2-digit codes from the ANSI standard INCITS 38:2009 (supersedes FIPS 5-2)  USPS 2-letter codes used by the United States Postal Service  USCG 2-letter codes used by the United States Coast Guard (bold red text shows differences between ANSI and USCG) Abbreviations:  GPO Older variable-length official US Government Printing Office abbreviations  AP Abbreviations from the AP Stylebook (bold red text shows differences between GPO and AP).5  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# ...
# 10                                               U.S.
# 11                                               Ala.
#
#    Codes:  ISO ISO 3166 codes (2-letter, 3-letter, and 3-digit codes from ISO 3166-1; 2+2-letter codes from ISO 3166-2)  ANSI 2-letter and 2-digit codes from the ANSI standard INCITS 38:2009 (supersedes FIPS 5-2)  USPS 2-letter codes used by the United States Postal Service  USCG 2-letter codes used by the United States Coast Guard (bold red text shows differences between ANSI and USCG) Abbreviations:  GPO Older variable-length official US Government Printing Office abbreviations  AP Abbreviations from the AP Stylebook (bold red text shows differences between GPO and AP).8  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                  AP
# 9                                                  AP
# 10                                               U.S.
# 11                                               Ala.
#
#    Codes:  ISO ISO 3166 codes (2-letter, 3-letter, and 3-digit codes from ISO 3166-1; 2+2-letter codes from ISO 3166-2)  ANSI 2-letter and 2-digit codes from the ANSI standard INCITS 38:2009 (supersedes FIPS 5-2)  USPS 2-letter codes used by the United States Postal Service  USCG 2-letter codes used by the United States Coast Guard (bold red text shows differences between ANSI and USCG) Abbreviations:  GPO Older variable-length official US Government Printing Office abbreviations  AP Abbreviations from the AP Stylebook (bold red text shows differences between GPO and AP).9
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                  Otherabbreviations
# 9                                  Otherabbreviations
# 10                                             U.S.A.
# 11                                                NaN

# %%
# remove unnecessary rows and columns
final_df = df_usa.drop(df_usa.index[range(0,11)])
final_df.head()
# Out:
#    Codes:  ISO ISO 3166 codes (2-letter, 3-letter, and 3-digit codes from ISO 3166-1; 2+2-letter codes from ISO 3166-2)  ANSI 2-letter and 2-digit codes from the ANSI standard INCITS 38:2009 (supersedes FIPS 5-2)  USPS 2-letter codes used by the United States Postal Service  USCG 2-letter codes used by the United States Coast Guard (bold red text shows differences between ANSI and USCG) Abbreviations:  GPO Older variable-length official US Government Printing Office abbreviations  AP Abbreviations from the AP Stylebook (bold red text shows differences between GPO and AP)  \
# 11                                            Alabama
# 12                                             Alaska
# 13                                            Arizona
# 14                                           Arkansas
# 15                                         California
#
#    Codes:  ISO ISO 3166 codes (2-letter, 3-letter, and 3-digit codes from ISO 3166-1; 2+2-letter codes from ISO 3166-2)  ANSI 2-letter and 2-digit codes from the ANSI standard INCITS 38:2009 (supersedes FIPS 5-2)  USPS 2-letter codes used by the United States Postal Service  USCG 2-letter codes used by the United States Coast Guard (bold red text shows differences between ANSI and USCG) Abbreviations:  GPO Older variable-length official US Government Printing Office abbreviations  AP Abbreviations from the AP Stylebook (bold red text shows differences between GPO and AP).1  \
# 11                                              State
# 12                                              State
# 13                                              State
# 14                                              State
# 15                                              State
#
#    Codes:  ISO ISO 3166 codes (2-letter, 3-letter, and 3-digit codes from ISO 3166-1; 2+2-letter codes from ISO 3166-2)  ANSI 2-letter and 2-digit codes from the ANSI standard INCITS 38:2009 (supersedes FIPS 5-2)  USPS 2-letter codes used by the United States Postal Service  USCG 2-letter codes used by the United States Coast Guard (bold red text shows differences between ANSI and USCG) Abbreviations:  GPO Older variable-length official US Government Printing Office abbreviations  AP Abbreviations from the AP Stylebook (bold red text shows differences between GPO and AP).2  \
# 11                                              US-AL
# 12                                              US-AK
# 13                                              US-AZ
# 14                                              US-AR
# 15                                              US-CA
#
#    Codes:  ISO ISO 3166 codes (2-letter, 3-letter, and 3-digit codes from ISO 3166-1; 2+2-letter codes from ISO 3166-2)  ANSI 2-letter and 2-digit codes from the ANSI standard INCITS 38:2009 (supersedes FIPS 5-2)  USPS 2-letter codes used by the United States Postal Service  USCG 2-letter codes used by the United States Coast Guard (bold red text shows differences between ANSI and USCG) Abbreviations:  GPO Older variable-length official US Government Printing Office abbreviations  AP Abbreviations from the AP Stylebook (bold red text shows differences between GPO and AP).3  \
# 11                                                 AL
# 12                                                 AK
# 13                                                 AZ
# 14                                                 AR
# 15                                                 CA
#
#    Codes:  ISO ISO 3166 codes (2-letter, 3-letter, and 3-digit codes from ISO 3166-1; 2+2-letter codes from ISO 3166-2)  ANSI 2-letter and 2-digit codes from the ANSI standard INCITS 38:2009 (supersedes FIPS 5-2)  USPS 2-letter codes used by the United States Postal Service  USCG 2-letter codes used by the United States Coast Guard (bold red text shows differences between ANSI and USCG) Abbreviations:  GPO Older variable-length official US Government Printing Office abbreviations  AP Abbreviations from the AP Stylebook (bold red text shows differences between GPO and AP).4  \
# 11                                                 01
# 12                                                 02
# 13                                                 04
# 14                                                 05
# 15                                                 06
#
#    Codes:  ISO ISO 3166 codes (2-letter, 3-letter, and 3-digit codes from ISO 3166-1; 2+2-letter codes from ISO 3166-2)  ANSI 2-letter and 2-digit codes from the ANSI standard INCITS 38:2009 (supersedes FIPS 5-2)  USPS 2-letter codes used by the United States Postal Service  USCG 2-letter codes used by the United States Coast Guard (bold red text shows differences between ANSI and USCG) Abbreviations:  GPO Older variable-length official US Government Printing Office abbreviations  AP Abbreviations from the AP Stylebook (bold red text shows differences between GPO and AP).5  \
# 11                                                 AL
# 12                                                 AK
# 13                                                 AZ
# 14                                                 AR
# 15                                                 CA
#
#    Codes:  ISO ISO 3166 codes (2-letter, 3-letter, and 3-digit codes from ISO 3166-1; 2+2-letter codes from ISO 3166-2)  ANSI 2-letter and 2-digit codes from the ANSI standard INCITS 38:2009 (supersedes FIPS 5-2)  USPS 2-letter codes used by the United States Postal Service  USCG 2-letter codes used by the United States Coast Guard (bold red text shows differences between ANSI and USCG) Abbreviations:  GPO Older variable-length official US Government Printing Office abbreviations  AP Abbreviations from the AP Stylebook (bold red text shows differences between GPO and AP).6  \
# 11                                                 AL
# 12                                                 AK
# 13                                                 AZ
# 14                                                 AR
# 15                                                 CF
#
#    Codes:  ISO ISO 3166 codes (2-letter, 3-letter, and 3-digit codes from ISO 3166-1; 2+2-letter codes from ISO 3166-2)  ANSI 2-letter and 2-digit codes from the ANSI standard INCITS 38:2009 (supersedes FIPS 5-2)  USPS 2-letter codes used by the United States Postal Service  USCG 2-letter codes used by the United States Coast Guard (bold red text shows differences between ANSI and USCG) Abbreviations:  GPO Older variable-length official US Government Printing Office abbreviations  AP Abbreviations from the AP Stylebook (bold red text shows differences between GPO and AP).7  \
# 11                                               Ala.
# 12                                             Alaska
# 13                                              Ariz.
# 14                                               Ark.
# 15                                             Calif.
#
#    Codes:  ISO ISO 3166 codes (2-letter, 3-letter, and 3-digit codes from ISO 3166-1; 2+2-letter codes from ISO 3166-2)  ANSI 2-letter and 2-digit codes from the ANSI standard INCITS 38:2009 (supersedes FIPS 5-2)  USPS 2-letter codes used by the United States Postal Service  USCG 2-letter codes used by the United States Coast Guard (bold red text shows differences between ANSI and USCG) Abbreviations:  GPO Older variable-length official US Government Printing Office abbreviations  AP Abbreviations from the AP Stylebook (bold red text shows differences between GPO and AP).8  \
# 11                                               Ala.
# 12                                             Alaska
# 13                                              Ariz.
# 14                                               Ark.
# 15                                             Calif.
#
#    Codes:  ISO ISO 3166 codes (2-letter, 3-letter, and 3-digit codes from ISO 3166-1; 2+2-letter codes from ISO 3166-2)  ANSI 2-letter and 2-digit codes from the ANSI standard INCITS 38:2009 (supersedes FIPS 5-2)  USPS 2-letter codes used by the United States Postal Service  USCG 2-letter codes used by the United States Coast Guard (bold red text shows differences between ANSI and USCG) Abbreviations:  GPO Older variable-length official US Government Printing Office abbreviations  AP Abbreviations from the AP Stylebook (bold red text shows differences between GPO and AP).9
# 11                                                NaN
# 12                                             Ak.[1]
# 13                                                NaN
# 14                                                NaN
# 15                                               Cal.

# %%
# rename columns
final_df.columns = ['Region Name', 'Region Status', 'ISO', 'ANSI_Letter', 'ANSI_Code'
                         , 'USPS', 'USCG','GPO', 'AP', 'Other Abbreviations']
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 77 entries, 11 to 87
# Data columns (total 10 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Region Name          77 non-null     object
#  1   Region Status        77 non-null     object
#  2   ISO                  72 non-null     object
#  3   ANSI_Letter          60 non-null     object
#  4   ANSI_Code            69 non-null     object
#  5   USPS                 67 non-null     object
#  6   USCG                 56 non-null     object
#  7   GPO                  56 non-null     object
#  8   AP                   51 non-null     object
#  9   Other Abbreviations  36 non-null     object
# dtypes: object(10)
# memory usage: 6.6+ KB

# %%
# reset index of rows
final_df.reset_index(drop=True)
# Out:
#                                Region Name            Region Status  \
# 0                                  Alabama                    State
# 1                                   Alaska                    State
# 2                                  Arizona                    State
# 3                                 Arkansas                    State
# 4                               California                    State
# ..                                     ...                      ...
# 72                                Nebraska  Obsolete postal code[g]
# 73                Northern Mariana Islands  Obsolete postal code[h]
# 74                       Panama Canal Zone     Obsolete postal code
# 75                      Philippine Islands     Obsolete postal code
# 76  Trust Territory of the Pacific Islands     Obsolete postal code
#
#             ISO ANSI_Letter ANSI_Code USPS USCG     GPO      AP  \
# 0         US-AL          AL        01   AL   AL    Ala.    Ala.
# 1         US-AK          AK        02   AK   AK  Alaska  Alaska
# 2         US-AZ          AZ        04   AZ   AZ   Ariz.   Ariz.
# 3         US-AR          AR        05   AR   AR    Ark.    Ark.
# 4         US-CA          CA        06   CA   CF  Calif.  Calif.
# ..          ...         ...       ...  ...  ...     ...     ...
# 72          NaN         NaN       NaN   NB  NaN     NaN     NaN
# 73          NaN         NaN       NaN   CM  NaN     NaN     NaN
# 74     PZPCZ594         NaN       NaN   CZ  NaN     NaN     NaN
# 75  PHPHL608[9]         NaN       NaN   PI  NaN     NaN     NaN
# 76     PCPCI582         NaN       NaN   TT  NaN     NaN     NaN
#
#    Other Abbreviations
# 0                  NaN
# 1               Ak.[1]
# 2                  NaN
# 3                  NaN
# 4                 Cal.
# ..                 ...
# 72                 NaN
# 73                 NaN
# 74                 NaN
# 75                 NaN
# 76                 NaN
#
# [77 rows x 10 columns]
